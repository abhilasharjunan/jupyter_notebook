# %%
import pandas as pd
df = pd.read_csv("C:/Personal/Finance/Stocks/Trading/itc/01-05-2019-TO-30-04-2020RELIANCEEQN.csv",usecols = lambda column : column not in 
["Average Price" , "Total Traded Quantity", "Turnover","No. of Trades", "Deliverable Qty","% Dly Qt to Traded Qty", "Series",""]);
df["Profit"] = df['Open Price'] - df['Prev Close']
df["Profit"].sum()
# Out:
# 745.2000000000016

# %%
df["Profit"].plot()

# %%
pip install datetime
# Out:
# Collecting datetime
#   Downloading https://files.pythonhosted.org/packages/73/22/a5297f3a1f92468cc737f8ce7ba6e5f245fcfafeae810ba37bd1039ea01c/DateTime-4.3-py2.py3-none-any.whl (60kB)
# Requirement already satisfied: pytz in c:\users\aarjunan\appdata\local\continuum\anaconda3\lib\site-packages (from datetime) (2018.9)
# Requirement already satisfied: zope.interface in c:\users\aarjunan\appdata\local\continuum\anaconda3\lib\site-packages (from datetime) (4.6.0)
# Requirement already satisfied: setuptools in c:\users\aarjunan\appdata\local\continuum\anaconda3\lib\site-packages (from zope.interface->datetime) (40.8.0)
# Installing collected packages: datetime
# Successfully installed datetime-4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import nsepy as ny
from datetime import date

# %%
sbin = ny.get_history(symbol='SBIN',
                    start=date(2019,1,1), 
                    end=date(2019,12,31), index=True)

# %%
print(sbin)

# %%
sbin?

# %%
pip uninstall nsepy

# %%
pip install nsepy
